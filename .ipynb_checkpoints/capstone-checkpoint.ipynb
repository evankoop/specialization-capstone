# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.patches import Circle
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import seaborn as sns
# %matplotlib inline
from scipy.stats import spearmanr
from scipy.stats import pearsonr

# %%
new_jazz_df = pd.read_csv('new_jazz_data.csv')
new_jazz_df.head()
# Out:
#               Name   Season  Age   Tm   Lg  Pos   G    MP   PER    TS%  ...  \
# 0  Lauri Markkanen  2019-20   22  CHI  NBA   PF  50  1492  14.3  0.560  ...
# 1  Lauri Markkanen  2020-21   23  CHI  NBA   PF  51  1317  15.2  0.619  ...
# 2  Lauri Markkanen  2021-22   24  CLE  NBA   SF  61  1878  14.7  0.582  ...
# 3     Kelly Olynyk  2019-20   28  MIA  NBA    C  67  1300  14.6  0.621  ...
# 4     Kelly Olynyk  2020-21   29  TOT  NBA  CPF  70  1997  16.4  0.610  ...
#
#    Unnamed: 20  OWS  DWS   WS  WS/48  Unnamed: 25  OBPM  DBPM  BPM  VORP
# 0          NaN  1.0  1.6  2.6  0.084          NaN   0.2  -0.8 -0.6   0.5
# 1          NaN  1.7  1.3  3.0  0.109          NaN   1.0  -0.9  0.1   0.7
# 2          NaN  2.7  2.3  5.0  0.127          NaN   0.4  -0.1  0.4   1.1
# 3          NaN  1.9  1.8  3.7  0.135          NaN   0.0   1.0  1.0   1.0
# 4          NaN  2.5  2.6  5.1  0.121          NaN   0.3   0.9  1.2   1.6
#
# [5 rows x 30 columns]

# %%
new_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         24 non-null     object
#  1   Season       24 non-null     object
#  2   Age          24 non-null     int64
#  3   Tm           24 non-null     object
#  4   Lg           24 non-null     object
#  5   Pos          24 non-null     object
#  6   G            24 non-null     int64
#  7   MP           24 non-null     int64
#  8   PER          24 non-null     float64
#  9   TS%          24 non-null     float64
#  10  3PAr         24 non-null     float64
#  11  FTr          24 non-null     float64
#  12  ORB%         24 non-null     float64
#  13  DRB%         24 non-null     float64
#  14  TRB%         24 non-null     float64
#  15  AST%         24 non-null     float64
#  16  STL%         24 non-null     float64
#  17  BLK%         24 non-null     float64
# ...

# %%
new_jazz_df = new_jazz_df.drop(['Unnamed: 20', 'Unnamed: 25'], axis=1)
new_jazz_df
# Out:
#                    Name   Season  Age   Tm   Lg  Pos   G    MP   PER    TS%  \
# 0       Lauri Markkanen  2019-20   22  CHI  NBA   PF  50  1492  14.3  0.560
# 1       Lauri Markkanen  2020-21   23  CHI  NBA   PF  51  1317  15.2  0.619
# 2       Lauri Markkanen  2021-22   24  CLE  NBA   SF  61  1878  14.7  0.582
# 3          Kelly Olynyk  2019-20   28  MIA  NBA    C  67  1300  14.6  0.621
# 4          Kelly Olynyk  2020-21   29  TOT  NBA  CPF  70  1997  16.4  0.610
# 5          Kelly Olynyk  2020-21   29  MIA  NBA    C  43  1157  12.1  0.549
# 6          Kelly Olynyk  2020-21   29  HOU  NBA   PF  27   840  22.3  0.674
# 7          Kelly Olynyk  2021-22   30  DET  NBA    C  40   764  16.7  0.561
# 8     Jarred Vanderbilt  2019-20   20  TOT  NBA   PF  11    46   7.6  0.676
# 9     Jarred Vanderbilt  2019-20   20  DEN  NBA   PF   9    41   7.2  0.714
# 10    Jarred Vanderbilt  2019-20   20  MIN  NBA   PF   2     5  11.1  0.532
# ...

# %%
new_jazz_df.columns = new_jazz_df.columns.str.lower()
new_jazz_df.head()
# Out:
#               name   season  age   tm   lg  pos   g    mp   per    ts%  ...  \
# 0  Lauri Markkanen  2019-20   22  CHI  NBA   PF  50  1492  14.3  0.560  ...
# 1  Lauri Markkanen  2020-21   23  CHI  NBA   PF  51  1317  15.2  0.619  ...
# 2  Lauri Markkanen  2021-22   24  CLE  NBA   SF  61  1878  14.7  0.582  ...
# 3     Kelly Olynyk  2019-20   28  MIA  NBA    C  67  1300  14.6  0.621  ...
# 4     Kelly Olynyk  2020-21   29  TOT  NBA  CPF  70  1997  16.4  0.610  ...
#
#    tov%  usg%  ows  dws   ws  ws/48  obpm  dbpm  bpm  vorp
# 0  11.0  21.1  1.0  1.6  2.6  0.084   0.2  -0.8 -0.6   0.5
# 1   8.5  20.2  1.7  1.3  3.0  0.109   1.0  -0.9  0.1   0.7
# 2   6.5  19.5  2.7  2.3  5.0  0.127   0.4  -0.1  0.4   1.1
# 3  13.8  17.4  1.9  1.8  3.7  0.135   0.0   1.0  1.0   1.0
# 4  14.0  19.7  2.5  2.6  5.1  0.121   0.3   0.9  1.2   1.6
#
# [5 rows x 28 columns]

# %%
new_jazz_df.isna().sum()
# Out:
# name      0
# season    0
# age       0
# tm        0
# lg        0
# pos       0
# g         0
# mp        0
# per       0
# ts%       0
# 3par      0
# ftr       0
# orb%      0
# drb%      0
# trb%      0
# ast%      0
# stl%      0
# blk%      0
# tov%      0
# usg%      0
# ows       0
# dws       0
# ws        0
# ws/48     0
# obpm      0
# dbpm      0
# bpm       0
# vorp      0
# dtype: int64

# %%
new_jazz_df['name'] = new_jazz_df['name'].astype(str)
new_jazz_df['season'] = new_jazz_df['season'].astype(str)
new_jazz_df['age'] = new_jazz_df['age'].astype(str)
new_jazz_df['tm'] = new_jazz_df['tm'].astype(str)
new_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    24 non-null     object
#  1   season  24 non-null     object
#  2   age     24 non-null     object
#  3   tm      24 non-null     object
#  4   lg      24 non-null     object
#  5   pos     24 non-null     object
#  6   g       24 non-null     int64
#  7   mp      24 non-null     int64
#  8   per     24 non-null     float64
#  9   ts%     24 non-null     float64
#  10  3par    24 non-null     float64
#  11  ftr     24 non-null     float64
#  12  orb%    24 non-null     float64
#  13  drb%    24 non-null     float64
#  14  trb%    24 non-null     float64
#  15  ast%    24 non-null     float64
#  16  stl%    24 non-null     float64
#  17  blk%    24 non-null     float64
#  18  tov%    24 non-null     float64
#  19  usg%    24 non-null     float64
#  20  ows     24 non-null     float64
# ...

# %%
new_jazz_df = new_jazz_df.drop('lg', axis=1)
new_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    24 non-null     object
#  1   season  24 non-null     object
#  2   age     24 non-null     object
#  3   tm      24 non-null     object
#  4   pos     24 non-null     object
#  5   g       24 non-null     int64
#  6   mp      24 non-null     int64
#  7   per     24 non-null     float64
#  8   ts%     24 non-null     float64
#  9   3par    24 non-null     float64
#  10  ftr     24 non-null     float64
#  11  orb%    24 non-null     float64
#  12  drb%    24 non-null     float64
#  13  trb%    24 non-null     float64
#  14  ast%    24 non-null     float64
#  15  stl%    24 non-null     float64
#  16  blk%    24 non-null     float64
#  17  tov%    24 non-null     float64
#  18  usg%    24 non-null     float64
#  19  ows     24 non-null     float64
#  20  dws     24 non-null     float64
# ...

# %%
old_jazz_df = pd.read_csv('old_jazz_data.csv')
old_jazz_df.head()
# Out:
#                Name   Season  Age   Tm   Lg Pos   G    MP   PER    TS%  ...  \
# 0  Donovan Mitchell  2019-20   23  UTA  NBA  SG  69  2364  18.8  0.558  ...
# 1  Donovan Mitchell  2020-21   24  UTA  NBA  PG  53  1771  21.3  0.569  ...
# 2  Donovan Mitchell  2021-22   25  UTA  NBA  SG  67  2266  21.6  0.572  ...
# 3       Rudy Gobert  2019-20   27  UTA  NBA   C  68  2333  21.7  0.699  ...
# 4       Rudy Gobert  2020-21   28  UTA  NBA   C  71  2187  23.5  0.683  ...
#
#    Unnamed: 20  OWS  DWS    WS  WS/48  Unnamed: 25  OBPM  DBPM  BPM  VORP
# 0          NaN  3.2  2.2   5.4  0.110          NaN   2.4  -0.6  1.9   2.3
# 1          NaN  3.9  2.2   6.2  0.167          NaN   4.6  -0.2  4.3   2.8
# 2          NaN  4.7  2.5   7.2  0.152          NaN   4.6  -0.3  4.3   3.6
# 3          NaN  6.5  4.2  10.7  0.221          NaN   1.7   1.9  3.6   3.3
# 4          NaN  6.1  5.2  11.3  0.248          NaN   2.1   2.8  4.9   3.8
#
# [5 rows x 30 columns]

# %%
old_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 30 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         12 non-null     object
#  1   Season       12 non-null     object
#  2   Age          12 non-null     int64
#  3   Tm           12 non-null     object
#  4   Lg           12 non-null     object
#  5   Pos          12 non-null     object
#  6   G            12 non-null     int64
#  7   MP           12 non-null     int64
#  8   PER          12 non-null     float64
#  9   TS%          12 non-null     float64
#  10  3PAr         12 non-null     float64
#  11  FTr          12 non-null     float64
#  12  ORB%         12 non-null     float64
#  13  DRB%         12 non-null     float64
#  14  TRB%         12 non-null     float64
#  15  AST%         12 non-null     float64
#  16  STL%         12 non-null     float64
#  17  BLK%         12 non-null     float64
# ...

# %%
old_jazz_df = old_jazz_df.drop(['Unnamed: 20', 'Unnamed: 25'], axis=1)
old_jazz_df
# Out:
#                 Name   Season  Age   Tm   Lg Pos   G    MP   PER    TS%  ...  \
# 0   Donovan Mitchell  2019-20   23  UTA  NBA  SG  69  2364  18.8  0.558  ...
# 1   Donovan Mitchell  2020-21   24  UTA  NBA  PG  53  1771  21.3  0.569  ...
# 2   Donovan Mitchell  2021-22   25  UTA  NBA  SG  67  2266  21.6  0.572  ...
# 3        Rudy Gobert  2019-20   27  UTA  NBA   C  68  2333  21.7  0.699  ...
# 4        Rudy Gobert  2020-21   28  UTA  NBA   C  71  2187  23.5  0.683  ...
# 5        Rudy Gobert  2021-22   29  UTA  NBA   C  66  2120  24.7  0.732  ...
# 6      Royce O'Neale  2019-20   26  UTA  NBA  SF  71  2049   9.5  0.578  ...
# 7      Royce O'Neale  2020-21   27  UTA  NBA  SF  71  2241   9.9  0.599  ...
# 8      Royce O'Neale  2021-22   28  UTA  NBA  SF  77  2406  10.3  0.608  ...
# 9   Bojan Bogdanovic  2019-20   30  UTA  NBA  SF  63  2083  15.6  0.603  ...
# 10  Bojan Bogdanovic  2020-21   31  UTA  NBA  SF  72  2216  14.0  0.588  ...
# ...

# %%
old_jazz_df.isna().sum()
# Out:
# Name      0
# Season    0
# Age       0
# Tm        0
# Lg        0
# Pos       0
# G         0
# MP        0
# PER       0
# TS%       0
# 3PAr      0
# FTr       0
# ORB%      0
# DRB%      0
# TRB%      0
# AST%      0
# STL%      0
# BLK%      0
# TOV%      0
# USG%      0
# OWS       0
# DWS       0
# WS        0
# WS/48     0
# OBPM      0
# DBPM      0
# BPM       0
# VORP      0
# dtype: int64

# %%
old_jazz_df.columns = old_jazz_df.columns.str.lower()
old_jazz_df.head()
# Out:
#                name   season  age   tm   lg pos   g    mp   per    ts%  ...  \
# 0  Donovan Mitchell  2019-20   23  UTA  NBA  SG  69  2364  18.8  0.558  ...
# 1  Donovan Mitchell  2020-21   24  UTA  NBA  PG  53  1771  21.3  0.569  ...
# 2  Donovan Mitchell  2021-22   25  UTA  NBA  SG  67  2266  21.6  0.572  ...
# 3       Rudy Gobert  2019-20   27  UTA  NBA   C  68  2333  21.7  0.699  ...
# 4       Rudy Gobert  2020-21   28  UTA  NBA   C  71  2187  23.5  0.683  ...
#
#    tov%  usg%  ows  dws    ws  ws/48  obpm  dbpm  bpm  vorp
# 0  11.0  30.8  3.2  2.2   5.4  0.110   2.4  -0.6  1.9   2.3
# 1  10.7  33.5  3.9  2.2   6.2  0.167   4.6  -0.2  4.3   2.8
# 2  11.7  32.9  4.7  2.5   7.2  0.152   4.6  -0.3  4.3   3.6
# 3  15.0  16.2  6.5  4.2  10.7  0.221   1.7   1.9  3.6   3.3
# 4  13.7  17.0  6.1  5.2  11.3  0.248   2.1   2.8  4.9   3.8
#
# [5 rows x 28 columns]

# %%
old_jazz_df['name'] = old_jazz_df['name'].astype(str)
old_jazz_df['season'] = old_jazz_df['season'].astype(str)
old_jazz_df['age'] = old_jazz_df['age'].astype(str)
old_jazz_df['tm'] = old_jazz_df['tm'].astype(str)
old_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    12 non-null     object
#  1   season  12 non-null     object
#  2   age     12 non-null     object
#  3   tm      12 non-null     object
#  4   lg      12 non-null     object
#  5   pos     12 non-null     object
#  6   g       12 non-null     int64
#  7   mp      12 non-null     int64
#  8   per     12 non-null     float64
#  9   ts%     12 non-null     float64
#  10  3par    12 non-null     float64
#  11  ftr     12 non-null     float64
#  12  orb%    12 non-null     float64
#  13  drb%    12 non-null     float64
#  14  trb%    12 non-null     float64
#  15  ast%    12 non-null     float64
#  16  stl%    12 non-null     float64
#  17  blk%    12 non-null     float64
#  18  tov%    12 non-null     float64
#  19  usg%    12 non-null     float64
#  20  ows     12 non-null     float64
# ...

# %%
old_jazz_df = old_jazz_df.drop('lg', axis=1)
old_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    12 non-null     object
#  1   season  12 non-null     object
#  2   age     12 non-null     object
#  3   tm      12 non-null     object
#  4   pos     12 non-null     object
#  5   g       12 non-null     int64
#  6   mp      12 non-null     int64
#  7   per     12 non-null     float64
#  8   ts%     12 non-null     float64
#  9   3par    12 non-null     float64
#  10  ftr     12 non-null     float64
#  11  orb%    12 non-null     float64
#  12  drb%    12 non-null     float64
#  13  trb%    12 non-null     float64
#  14  ast%    12 non-null     float64
#  15  stl%    12 non-null     float64
#  16  blk%    12 non-null     float64
#  17  tov%    12 non-null     float64
#  18  usg%    12 non-null     float64
#  19  ows     12 non-null     float64
#  20  dws     12 non-null     float64
# ...

# %%
old_jazz_df
# Out:
#                 name   season age   tm pos   g    mp   per    ts%   3par  ...  \
# 0   Donovan Mitchell  2019-20  23  UTA  SG  69  2364  18.8  0.558  0.352  ...
# 1   Donovan Mitchell  2020-21  24  UTA  PG  53  1771  21.3  0.569  0.423  ...
# 2   Donovan Mitchell  2021-22  25  UTA  SG  67  2266  21.6  0.572  0.475  ...
# 3        Rudy Gobert  2019-20  27  UTA   C  68  2333  21.7  0.699  0.000  ...
# 4        Rudy Gobert  2020-21  28  UTA   C  71  2187  23.5  0.683  0.007  ...
# 5        Rudy Gobert  2021-22  29  UTA   C  66  2120  24.7  0.732  0.008  ...
# 6      Royce O'Neale  2019-20  26  UTA  SF  71  2049   9.5  0.578  0.668  ...
# 7      Royce O'Neale  2020-21  27  UTA  SF  71  2241   9.9  0.599  0.706  ...
# 8      Royce O'Neale  2021-22  28  UTA  SF  77  2406  10.3  0.608  0.689  ...
# 9   Bojan Bogdanovic  2019-20  30  UTA  SF  63  2083  15.6  0.603  0.489  ...
# 10  Bojan Bogdanovic  2020-21  31  UTA  SF  72  2216  14.0  0.588  0.498  ...
# ...

# %%
new_jazz_df['ts%'].mean()
# Out:
# 0.57975

# %%
old_jazz_df['ts%'].mean()
# Out:
# 0.6156666666666667

# %%
new_jazz_df['tov%'].mean()
# Out:
# 14.383333333333333

# %%
old_jazz_df['tov%'].mean()
# Out:
# 12.950000000000001

# %%
new_jazz_df['ast%'].mean()
# Out:
# 11.5875

# %%
old_jazz_df['ast%'].mean()
# Out:
# 12.824999999999998

# %%
new_jazz_df['stl%'].mean()
# Out:
# 1.8916666666666666

# %%
old_jazz_df['stl%'].mean()
# Out:
# 1.2500000000000002

# %%
new_jazz_df['vorp'].mean()
# Out:
# 0.44583333333333336

# %%
old_jazz_df['vorp'].mean()
# Out:
# 2.2833333333333337

# %%
new_jazz_df['ws/48'].mean()
# Out:
# 0.07708333333333334

# %%
old_jazz_df['ws/48'].mean()
# Out:
# 0.15166666666666664

# %%
new_jazz_df['3par'].mean()
# Out:
# 0.41825

# %%
old_jazz_df['3par'].mean()
# Out:
# 0.40158333333333324

# %%
old_jazz_df['dbpm'].mean()
# Out:
# 0.625

# %%
new_jazz_df['dbpm'].mean()
# Out:
# -0.21666666666666667

# %%
new_jazz_df['obpm'].mean()
# Out:
# -1.0624999999999998

# %%
old_jazz_df['obpm'].mean()
# Out:
# 1.5333333333333332

# %%
new_jazz_2_df = pd.read_csv('new_jazz_data_2.csv')
old_jazz_2_df = pd.read_csv('old_jazz_data_2.csv')

# %%
new_jazz_2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    24 non-null     object
#  1   Season  24 non-null     object
#  2   Age     24 non-null     int64
#  3   Tm      24 non-null     object
#  4   Lg      24 non-null     object
#  5   Pos     24 non-null     object
#  6   G       24 non-null     int64
#  7   GS      24 non-null     int64
#  8   MP      24 non-null     float64
#  9   FG      24 non-null     float64
#  10  FGA     24 non-null     float64
#  11  FG%     24 non-null     float64
#  12  3P      24 non-null     float64
#  13  3PA     24 non-null     float64
#  14  3P%     23 non-null     float64
#  15  2P      24 non-null     float64
#  16  2PA     24 non-null     float64
#  17  2P%     23 non-null     float64
#  18  eFG%    24 non-null     float64
#  19  FT      24 non-null     float64
#  20  FTA     24 non-null     float64
# ...

# %%
new_jazz_2_df.columns = new_jazz_2_df.columns.str.lower()
new_jazz_2_df.head()
# Out:
#               name   season  age   tm   lg  pos   g  gs    mp   fg  ...  \
# 0  Lauri Markkanen  2019-20   22  CHI  NBA   PF  50  50  29.8  5.0  ...
# 1  Lauri Markkanen  2020-21   23  CHI  NBA   PF  51  26  25.8  4.9  ...
# 2  Lauri Markkanen  2021-22   24  CLE  NBA   SF  61  61  30.8  5.1  ...
# 3     Kelly Olynyk  2019-20   28  MIA  NBA    C  67   9  19.4  2.7  ...
# 4     Kelly Olynyk  2020-21   29  TOT  NBA  CPF  70  62  28.5  4.8  ...
#
#      ft%  orb  drb  trb  ast  stl  blk  tov   pf   pts
# 0  0.824  1.2  5.1  6.3  1.5  0.8  0.5  1.6  1.9  14.7
# 1  0.826  0.7  4.6  5.3  0.9  0.5  0.3  1.0  1.5  13.6
# 2  0.868  1.0  4.7  5.7  1.3  0.7  0.5  0.9  2.1  14.8
# 3  0.860  0.7  3.9  4.6  1.7  0.7  0.3  1.1  2.6   8.2
# 4  0.829  1.2  5.7  7.0  2.9  1.1  0.6  1.8  3.0  13.5
#
# [5 rows x 31 columns]

# %%
new_jazz_df = new_jazz_df.join(new_jazz_2_df.set_index(['name', 'season']), on=['name', 'season'], how='inner',
                              lsuffix='_x', rsuffix='_y')

# %%
new_jazz_df
new_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 23
# Data columns (total 56 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    42 non-null     object
#  1   season  42 non-null     object
#  2   age_x   42 non-null     object
#  3   tm_x    42 non-null     object
#  4   pos_x   42 non-null     object
#  5   g_x     42 non-null     int64
#  6   mp_x    42 non-null     int64
#  7   per     42 non-null     float64
#  8   ts%     42 non-null     float64
#  9   3par    42 non-null     float64
#  10  ftr     42 non-null     float64
#  11  orb%    42 non-null     float64
#  12  drb%    42 non-null     float64
#  13  trb%    42 non-null     float64
#  14  ast%    42 non-null     float64
#  15  stl%    42 non-null     float64
#  16  blk%    42 non-null     float64
#  17  tov%    42 non-null     float64
#  18  usg%    42 non-null     float64
#  19  ows     42 non-null     float64
#  20  dws     42 non-null     float64
# ...

# %%
new_jazz_df = new_jazz_df.drop(columns=['age_y', 'tm_y', 'lg', 'pos_y', 'g_y', 'mp_y'], axis=1)
new_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 23
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    42 non-null     object
#  1   season  42 non-null     object
#  2   age_x   42 non-null     object
#  3   tm_x    42 non-null     object
#  4   pos_x   42 non-null     object
#  5   g_x     42 non-null     int64
#  6   mp_x    42 non-null     int64
#  7   per     42 non-null     float64
#  8   ts%     42 non-null     float64
#  9   3par    42 non-null     float64
#  10  ftr     42 non-null     float64
#  11  orb%    42 non-null     float64
#  12  drb%    42 non-null     float64
#  13  trb%    42 non-null     float64
#  14  ast%    42 non-null     float64
#  15  stl%    42 non-null     float64
#  16  blk%    42 non-null     float64
#  17  tov%    42 non-null     float64
#  18  usg%    42 non-null     float64
#  19  ows     42 non-null     float64
#  20  dws     42 non-null     float64
# ...

# %%
new_jazz_df = new_jazz_df.rename(columns={'age_x':'age', 'tm_x':'tm', 'pos_x':'pos', 'g_x':'g', 'mp_x':'mp'})
new_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 23
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    42 non-null     object
#  1   season  42 non-null     object
#  2   age     42 non-null     object
#  3   tm      42 non-null     object
#  4   pos     42 non-null     object
#  5   g       42 non-null     int64
#  6   mp      42 non-null     int64
#  7   per     42 non-null     float64
#  8   ts%     42 non-null     float64
#  9   3par    42 non-null     float64
#  10  ftr     42 non-null     float64
#  11  orb%    42 non-null     float64
#  12  drb%    42 non-null     float64
#  13  trb%    42 non-null     float64
#  14  ast%    42 non-null     float64
#  15  stl%    42 non-null     float64
#  16  blk%    42 non-null     float64
#  17  tov%    42 non-null     float64
#  18  usg%    42 non-null     float64
#  19  ows     42 non-null     float64
#  20  dws     42 non-null     float64
# ...

# %%
old_jazz_2_df.columns = old_jazz_2_df.columns.str.lower()
old_jazz_2_df.head()
# Out:
#                name   season  age   tm   lg pos   g  gs    mp   fg  ...  \
# 0  Donovan Mitchell  2019-20   23  UTA  NBA  SG  69  69  34.3  8.7  ...
# 1  Donovan Mitchell  2020-21   24  UTA  NBA  PG  53  53  33.4  9.0  ...
# 2  Donovan Mitchell  2021-22   25  UTA  NBA  SG  67  67  33.8  9.2  ...
# 3       Rudy Gobert  2019-20   27  UTA  NBA   C  68  68  34.3  5.7  ...
# 4       Rudy Gobert  2020-21   28  UTA  NBA   C  71  71  30.8  5.5  ...
#
#      ft%  orb   drb   trb  ast  stl  blk  tov   pf   pts
# 0  0.863  0.8   3.6   4.4  4.3  1.0  0.2  2.7  2.5  24.0
# 1  0.845  0.9   3.5   4.4  5.2  1.0  0.3  2.8  2.2  26.4
# 2  0.853  0.8   3.4   4.2  5.3  1.5  0.2  3.0  2.4  25.9
# 3  0.630  3.4  10.1  13.5  1.5  0.8  2.0  1.9  3.2  15.1
# 4  0.623  3.4  10.1  13.5  1.3  0.6  2.7  1.7  2.3  14.3
#
# [5 rows x 31 columns]

# %%
old_jazz_df = old_jazz_df.join(old_jazz_2_df.set_index(['name', 'season']), on=['name', 'season'], how='inner',
                              lsuffix='_x', rsuffix='_y')
old_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 11
# Data columns (total 56 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    12 non-null     object
#  1   season  12 non-null     object
#  2   age_x   12 non-null     object
#  3   tm_x    12 non-null     object
#  4   pos_x   12 non-null     object
#  5   g_x     12 non-null     int64
#  6   mp_x    12 non-null     int64
#  7   per     12 non-null     float64
#  8   ts%     12 non-null     float64
#  9   3par    12 non-null     float64
#  10  ftr     12 non-null     float64
#  11  orb%    12 non-null     float64
#  12  drb%    12 non-null     float64
#  13  trb%    12 non-null     float64
#  14  ast%    12 non-null     float64
#  15  stl%    12 non-null     float64
#  16  blk%    12 non-null     float64
#  17  tov%    12 non-null     float64
#  18  usg%    12 non-null     float64
#  19  ows     12 non-null     float64
#  20  dws     12 non-null     float64
# ...

# %%
old_jazz_df = old_jazz_df.drop(columns=['age_y', 'tm_y', 'lg', 'pos_y', 'g_y', 'mp_y'], axis=1)
old_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 11
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    12 non-null     object
#  1   season  12 non-null     object
#  2   age_x   12 non-null     object
#  3   tm_x    12 non-null     object
#  4   pos_x   12 non-null     object
#  5   g_x     12 non-null     int64
#  6   mp_x    12 non-null     int64
#  7   per     12 non-null     float64
#  8   ts%     12 non-null     float64
#  9   3par    12 non-null     float64
#  10  ftr     12 non-null     float64
#  11  orb%    12 non-null     float64
#  12  drb%    12 non-null     float64
#  13  trb%    12 non-null     float64
#  14  ast%    12 non-null     float64
#  15  stl%    12 non-null     float64
#  16  blk%    12 non-null     float64
#  17  tov%    12 non-null     float64
#  18  usg%    12 non-null     float64
#  19  ows     12 non-null     float64
#  20  dws     12 non-null     float64
# ...

# %%
old_jazz_df = old_jazz_df.rename(columns={'age_x':'age', 'tm_x':'tm', 'pos_x':'pos', 'g_x':'g', 'mp_x':'mp'})
old_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 11
# Data columns (total 50 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    12 non-null     object
#  1   season  12 non-null     object
#  2   age     12 non-null     object
#  3   tm      12 non-null     object
#  4   pos     12 non-null     object
#  5   g       12 non-null     int64
#  6   mp      12 non-null     int64
#  7   per     12 non-null     float64
#  8   ts%     12 non-null     float64
#  9   3par    12 non-null     float64
#  10  ftr     12 non-null     float64
#  11  orb%    12 non-null     float64
#  12  drb%    12 non-null     float64
#  13  trb%    12 non-null     float64
#  14  ast%    12 non-null     float64
#  15  stl%    12 non-null     float64
#  16  blk%    12 non-null     float64
#  17  tov%    12 non-null     float64
#  18  usg%    12 non-null     float64
#  19  ows     12 non-null     float64
#  20  dws     12 non-null     float64
# ...

# %%
dmitchell_df = old_jazz_df.loc[old_jazz_df['name'] == 'Donovan Mitchell']
dmitchell_df
# Out:
#                name   season age   tm pos   g    mp   per    ts%   3par  ...  \
# 0  Donovan Mitchell  2019-20  23  UTA  SG  69  2364  18.8  0.558  0.352  ...
# 1  Donovan Mitchell  2020-21  24  UTA  PG  53  1771  21.3  0.569  0.423  ...
# 2  Donovan Mitchell  2021-22  25  UTA  SG  67  2266  21.6  0.572  0.475  ...
#
#      ft%  orb  drb  trb  ast  stl  blk  tov   pf   pts
# 0  0.863  0.8  3.6  4.4  4.3  1.0  0.2  2.7  2.5  24.0
# 1  0.845  0.9  3.5  4.4  5.2  1.0  0.3  2.8  2.2  26.4
# 2  0.853  0.8  3.4  4.2  5.3  1.5  0.2  3.0  2.4  25.9
#
# [3 rows x 50 columns]

# %%
rgobert_df = old_jazz_df.loc[old_jazz_df['name'] == 'Rudy Gobert']
roneale_df = old_jazz_df.loc[old_jazz_df["name"] == "Royce O'Neale"]
bbogdanovic_df = old_jazz_df.loc[old_jazz_df['name'] == 'Bojan Bogdanovic']

# %%
plt.figure(figsize=(12,6))
plt.plot('season', 'efg%', data=dmitchell_df)
plt.plot('season', 'efg%', data=rgobert_df)
plt.plot('season', 'efg%', data=roneale_df)
plt.plot('season', 'efg%', data=bbogdanovic_df)
plt.legend(['Donovan Mitchell', 'Rudy Gobert', 'Royce O Neale', 'Bojan Bogdanovic'])
plt.ylim((0,1.0))
plt.title('Effective Field Goal Percentage for Former Jazz Players', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('eFG%', fontsize=12)
# Out:
# Text(0, 0.5, 'eFG%')

# %%
lmarkkanen_df = new_jazz_df.loc[new_jazz_df['name'] == 'Lauri Markkanen']
kolynyk_df = new_jazz_df.loc[new_jazz_df['name'] == 'Kelly Olynyk']
jvanderbilt_df = new_jazz_df.loc[new_jazz_df['name'] == 'Jarred Vanderbilt']
csexton_df = new_jazz_df.loc[new_jazz_df['name'] == 'Collin Sexton']
thortontucker_df = new_jazz_df.loc[new_jazz_df['name'] == 'Talen Horton-Tucker']
mbeasley_df = new_jazz_df.loc[new_jazz_df['name'] == 'Malik Beasley']

# %%
plt.figure(figsize=(12,6))
plt.plot('season', 'efg%', data=lmarkkanen_df)
plt.plot('season', 'efg%', data=kolynyk_df)
plt.plot('season', 'efg%', data=jvanderbilt_df)
plt.plot('season', 'efg%', data=csexton_df)
plt.plot('season', 'efg%', data=thortontucker_df)
plt.plot('season', 'efg%', data=mbeasley_df)
plt.legend(['Lauri Markkanen', 'Kelly Olynyk', 'Jarred Vanderbilt', 'Collin Sexton', 'Talen Horton-Tucker', 'Malik Beasley'])
plt.ylim((0,1.0))
plt.title('Effective Field Goal Percentage for New Jazz Players', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('eFG%', fontsize=12)
# Out:
# Text(0, 0.5, 'eFG%')

# %%
salary_df = pd.read_csv('salary_data.csv')
salary_df
# Out:
#                   name  2022-23_salary on-jazz
# 0     Donovan Mitchell        30351780       N
# 1          Rudy Gobert        38172414       N
# 2        Royce O'Neale         9200000       N
# 3     Bojan Bogdanovic        19343000       N
# 4      Lauri Markkanen        16475454       Y
# 5         Kelly Olynyk        12804878       Y
# 6    Jarred Vanderbilt         4320000       Y
# 7        Collin Sexton        16500000       Y
# 8  Talen Horton-Tucker        10260000       Y
# 9        Malik Beasley        15458035       Y

# %%
salary_df['name'] = salary_df['name'].astype(str)
salary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            10 non-null     object
#  1   2022-23_salary  10 non-null     int64
#  2   on-jazz         10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 368.0+ bytes

# %%
old_jazz_salary = salary_df.loc[:3]
new_jazz_salary = salary_df.loc[4:]

# %%
old_jazz_salary
# Out:
#                name  2022-23_salary on-jazz
# 0  Donovan Mitchell        30351780       N
# 1       Rudy Gobert        38172414       N
# 2     Royce O'Neale         9200000       N
# 3  Bojan Bogdanovic        19343000       N

# %%
new_jazz_salary
# Out:
#                   name  2022-23_salary on-jazz
# 4      Lauri Markkanen        16475454       Y
# 5         Kelly Olynyk        12804878       Y
# 6    Jarred Vanderbilt         4320000       Y
# 7        Collin Sexton        16500000       Y
# 8  Talen Horton-Tucker        10260000       Y
# 9        Malik Beasley        15458035       Y

# %%
old_jazz_salary['2022-23_salary'].mean()
# Out:
# 24266798.5

# %%
new_jazz_salary['2022-23_salary'].mean()
# Out:
# 12636394.5

# %%
plt.figure(figsize=(18,6))
name = salary_df['name']
salary = salary_df['2022-23_salary']
c = ['red', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'blue']
plt.bar(name,salary,color=c)
plt.ylim(0)
plt.title('Salary for Players (both former and current)')
plt.ylabel('2022-23 Salary (in tens of millions)')
sal_f = mpatches.Patch(color='red', label='Former Jazz Player')
sal_c = mpatches.Patch(color='blue', label='Current Jazz Player')
plt.legend(handles=[sal_f,sal_c])

# %%
old_jazz_salary['2022-23_salary'].sum()
# Out:
# 97067194

# %%
new_jazz_salary['2022-23_salary'].sum()
# Out:
# 75818367

# %%
plt.figure(figsize=(12,6))
plt.plot('season', 'tov%', data=lmarkkanen_df)
plt.plot('season', 'tov%', data=kolynyk_df)
plt.plot('season', 'tov%', data=jvanderbilt_df)
plt.plot('season', 'tov%', data=csexton_df)
plt.plot('season', 'tov%', data=thortontucker_df)
plt.plot('season', 'tov%', data=mbeasley_df)
plt.legend(['Lauri Markkanen', 'Kelly Olynyk', 'Jarred Vanderbilt', 'Collin Sexton', 'Talen Horton-Tucker', 'Malik Beasley'])
plt.ylim((0,20))
plt.title('Turnover Percentage for New Jazz Players', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('Tov%', fontsize=12)
# Out:
# Text(0, 0.5, 'Tov%')

# %%
plt.figure(figsize=(12,6))
plt.plot('season', 'tov%', data=dmitchell_df)
plt.plot('season', 'tov%', data=rgobert_df)
plt.plot('season', 'tov%', data=roneale_df)
plt.plot('season', 'tov%', data=bbogdanovic_df)
plt.legend(['Donovan Mitchell', 'Rudy Gobert', 'Royce O Neale', 'Bojan Bogdanovic'])
plt.ylim((0,20))
plt.title('Turnover Percentage for Former Jazz Players', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('Tov%', fontsize=12)
# Out:
# Text(0, 0.5, 'Tov%')

# %%
new_jazz_df['3p%'].mean()
# Out:
# 0.29471794871794876

# %%
old_jazz_df['3p%'].mean()
# Out:
# 0.31354545454545457

# %%
new_jazz_df['fg%'].mean()
# Out:
# 0.4589761904761905

# %%
old_jazz_df['fg%'].mean()
# Out:
# 0.5075833333333334

# %%
new_jazz_df['2p%'].mean()
# Out:
# 0.5709743589743589

# %%
old_jazz_df['2p%'].mean()
# Out:
# 0.5686666666666668

# %%
new_jazz_df['efg%'].mean()
# Out:
# 0.5239285714285713

# %%
old_jazz_df['efg%'].mean()
# Out:
# 0.5844166666666667

# %%
new_jazz_df['ft%'].mean()
# Out:
# 0.8247948717948719

# %%
old_jazz_df['ft%'].mean()
# Out:
# 0.7966666666666667

# %%
new_jazz_df['tov'].mean()
# Out:
# 1.2738095238095237

# %%
old_jazz_df['tov'].mean()
# Out:
# 1.9166666666666667

# %%
new_jazz_df['pf'].mean()
# Out:
# 1.788095238095239

# %%
old_jazz_df['pf'].mean()
# Out:
# 2.341666666666667

# %%
new_jazz_df['stl'].mean()
# Out:
# 0.7523809523809527

# %%
old_jazz_df['stl'].mean()
# Out:
# 0.8249999999999998

# %%
new_jazz_df['blk'].mean()
# Out:
# 0.2857142857142855

# %%
old_jazz_df['blk'].mean()
# Out:
# 0.7583333333333333

# %%
new_jazz_df['ast'].mean()
# Out:
# 1.7285714285714295

# %%
old_jazz_df['ast'].mean()
# Out:
# 2.6583333333333337

# %%
new_jazz_df['ts%'].mean()
# Out:
# 0.5885714285714287

# %%
old_jazz_df['ts%'].mean()
# Out:
# 0.6156666666666667

# %%
new_jazz_df['trb%'].mean()
# Out:
# 10.114285714285717

# %%
old_jazz_df['trb%'].mean()
# Out:
# 11.85

# %%
new_jazz_df['ftr'].mean()
# Out:
# 0.3308809523809523

# %%
old_jazz_df['ftr'].mean()
# Out:
# 0.3539166666666666

# %%
new_jazz_df['per'].mean()
# Out:
# 13.416666666666666

# %%
old_jazz_df['per'].mean()
# Out:
# 17.216666666666665

# %%
new_jazz_df['ows'].mean()
# Out:
# 0.8547619047619047

# %%
old_jazz_df['ows'].mean()
# Out:
# 3.9500000000000006

# %%
new_jazz_3_df = pd.read_csv('new_jazz_data_3.csv')
old_jazz_3_df = pd.read_csv('old_jazz_data_3.csv')

# %%
new_jazz_3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 36 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         24 non-null     object
#  1   Season       24 non-null     object
#  2   Age          24 non-null     int64
#  3   Tm           24 non-null     object
#  4   Lg           24 non-null     object
#  5   Pos          24 non-null     object
#  6   G            24 non-null     int64
#  7   MP           24 non-null     int64
#  8   FG%          24 non-null     float64
#  9   Dist.        24 non-null     float64
#  10  Unnamed: 10  0 non-null      float64
#  11  2P           24 non-null     float64
#  12  0-3          24 non-null     float64
#  13  3-10         24 non-null     float64
#  14  10-16        24 non-null     float64
#  15  16-3P        24 non-null     float64
#  16  3P           24 non-null     float64
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
new_jazz_3_df = new_jazz_3_df.drop(columns=['Unnamed: 10', 'Unnamed: 17', 'Unnamed: 24', 'Unnamed: 27', 'Unnamed: 30', 'Unnamed: 33'])
new_jazz_3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 30 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     24 non-null     object
#  1   Season   24 non-null     object
#  2   Age      24 non-null     int64
#  3   Tm       24 non-null     object
#  4   Lg       24 non-null     object
#  5   Pos      24 non-null     object
#  6   G        24 non-null     int64
#  7   MP       24 non-null     int64
#  8   FG%      24 non-null     float64
#  9   Dist.    24 non-null     float64
#  10  2P       24 non-null     float64
#  11  0-3      24 non-null     float64
#  12  3-10     24 non-null     float64
#  13  10-16    24 non-null     float64
#  14  16-3P    24 non-null     float64
#  15  3P       24 non-null     float64
#  16  2P.1     23 non-null     float64
#  17  0-3.1    23 non-null     float64
#  18  3-10.1   21 non-null     float64
#  19  10-16.1  21 non-null     float64
# ...

# %%
new_jazz_3_df = new_jazz_3_df.drop(columns=['Att.', '#.1', '3P%', '%3PA', '#', '%FGA', '3P.2', '2P.2', '3P.1', '2P.1', 'FG%', 'Lg'], axis=1)
new_jazz_3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     24 non-null     object
#  1   Season   24 non-null     object
#  2   Age      24 non-null     int64
#  3   Tm       24 non-null     object
#  4   Pos      24 non-null     object
#  5   G        24 non-null     int64
#  6   MP       24 non-null     int64
#  7   Dist.    24 non-null     float64
#  8   2P       24 non-null     float64
#  9   0-3      24 non-null     float64
#  10  3-10     24 non-null     float64
#  11  10-16    24 non-null     float64
#  12  16-3P    24 non-null     float64
#  13  3P       24 non-null     float64
#  14  0-3.1    23 non-null     float64
#  15  3-10.1   21 non-null     float64
#  16  10-16.1  21 non-null     float64
#  17  16-3P.1  19 non-null     float64
# dtypes: float64(11), int64(3), object(4)
# memory usage: 3.5+ KB

# %%
new_jazz_3_df = new_jazz_3_df.rename(columns={'FG%':'FG%bd', '2P':'2Pd', '3P':'3Pd'})
new_jazz_3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     24 non-null     object
#  1   Season   24 non-null     object
#  2   Age      24 non-null     int64
#  3   Tm       24 non-null     object
#  4   Pos      24 non-null     object
#  5   G        24 non-null     int64
#  6   MP       24 non-null     int64
#  7   Dist.    24 non-null     float64
#  8   2Pd      24 non-null     float64
#  9   0-3      24 non-null     float64
#  10  3-10     24 non-null     float64
#  11  10-16    24 non-null     float64
#  12  16-3P    24 non-null     float64
#  13  3Pd      24 non-null     float64
#  14  0-3.1    23 non-null     float64
#  15  3-10.1   21 non-null     float64
#  16  10-16.1  21 non-null     float64
#  17  16-3P.1  19 non-null     float64
# dtypes: float64(11), int64(3), object(4)
# memory usage: 3.5+ KB

# %%
new_jazz_3_df.columns = new_jazz_3_df.columns.str.lower()
new_jazz_3_df.head()
# Out:
#               name   season  age   tm  pos   g    mp  dist.    2pd    0-3  \
# 0  Lauri Markkanen  2019-20   22  CHI   PF  50  1492   15.5  0.464  0.274
# 1  Lauri Markkanen  2020-21   23  CHI   PF  51  1317   16.2  0.432  0.240
# 2  Lauri Markkanen  2021-22   24  CLE   SF  61  1878   16.5  0.459  0.226
# 3     Kelly Olynyk  2019-20   28  MIA    C  67  1300   17.6  0.412  0.221
# 4     Kelly Olynyk  2020-21   29  TOT  CPF  70  1997   15.6  0.472  0.286
#
#     3-10  10-16  16-3p    3pd  0-3.1  3-10.1  10-16.1  16-3p.1
# 0  0.149  0.027  0.014  0.536  0.648   0.341    0.313    0.250
# 1  0.146  0.033  0.013  0.568  0.672   0.553    0.235    0.143
# 2  0.144  0.061  0.028  0.541  0.679   0.446    0.326    0.500
# 3  0.098  0.055  0.038  0.588  0.693   0.359    0.455    0.267
# 4  0.135  0.030  0.022  0.528  0.769   0.479    0.286    0.467

# %%
new_jazz_3_df = new_jazz_3_df.fillna(0.000)

# %%
new_jazz_3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     24 non-null     object
#  1   season   24 non-null     object
#  2   age      24 non-null     int64
#  3   tm       24 non-null     object
#  4   pos      24 non-null     object
#  5   g        24 non-null     int64
#  6   mp       24 non-null     int64
#  7   dist.    24 non-null     float64
#  8   2pd      24 non-null     float64
#  9   0-3      24 non-null     float64
#  10  3-10     24 non-null     float64
#  11  10-16    24 non-null     float64
#  12  16-3p    24 non-null     float64
#  13  3pd      24 non-null     float64
#  14  0-3.1    24 non-null     float64
#  15  3-10.1   24 non-null     float64
#  16  10-16.1  24 non-null     float64
#  17  16-3p.1  24 non-null     float64
# dtypes: float64(11), int64(3), object(4)
# memory usage: 3.5+ KB

# %%
old_jazz_3_df = old_jazz_3_df.drop(columns=['Unnamed: 10', 'Unnamed: 17', 'Unnamed: 24', 'Unnamed: 27', 'Unnamed: 30', 'Unnamed: 33'])
old_jazz_3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 30 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     12 non-null     object
#  1   Season   12 non-null     object
#  2   Age      12 non-null     int64
#  3   Tm       12 non-null     object
#  4   Lg       12 non-null     object
#  5   Pos      12 non-null     object
#  6   G        12 non-null     int64
#  7   MP       12 non-null     int64
#  8   FG%      12 non-null     float64
#  9   Dist.    12 non-null     float64
#  10  2P       12 non-null     float64
#  11  0-3      12 non-null     float64
#  12  3-10     12 non-null     float64
#  13  10-16    12 non-null     float64
#  14  16-3P    12 non-null     float64
#  15  3P       12 non-null     float64
#  16  2P.1     12 non-null     float64
#  17  0-3.1    12 non-null     float64
#  18  3-10.1   12 non-null     float64
#  19  10-16.1  12 non-null     float64
# ...

# %%
old_jazz_3_df = old_jazz_3_df.drop(columns=['Att.', '#.1', '3P%', '%3PA', '#', '%FGA', '3P.2', '2P.2', '3P.1', '2P.1', 'FG%', 'Lg'], axis=1)
old_jazz_3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     12 non-null     object
#  1   Season   12 non-null     object
#  2   Age      12 non-null     int64
#  3   Tm       12 non-null     object
#  4   Pos      12 non-null     object
#  5   G        12 non-null     int64
#  6   MP       12 non-null     int64
#  7   Dist.    12 non-null     float64
#  8   2P       12 non-null     float64
#  9   0-3      12 non-null     float64
#  10  3-10     12 non-null     float64
#  11  10-16    12 non-null     float64
#  12  16-3P    12 non-null     float64
#  13  3P       12 non-null     float64
#  14  0-3.1    12 non-null     float64
#  15  3-10.1   12 non-null     float64
#  16  10-16.1  12 non-null     float64
#  17  16-3P.1  10 non-null     float64
# dtypes: float64(11), int64(3), object(4)
# memory usage: 1.8+ KB

# %%
old_jazz_3_df = old_jazz_3_df.rename(columns={'FG%':'FG%bd', '2P':'2Pd', '3P':'3Pd'})
old_jazz_3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     12 non-null     object
#  1   Season   12 non-null     object
#  2   Age      12 non-null     int64
#  3   Tm       12 non-null     object
#  4   Pos      12 non-null     object
#  5   G        12 non-null     int64
#  6   MP       12 non-null     int64
#  7   Dist.    12 non-null     float64
#  8   2Pd      12 non-null     float64
#  9   0-3      12 non-null     float64
#  10  3-10     12 non-null     float64
#  11  10-16    12 non-null     float64
#  12  16-3P    12 non-null     float64
#  13  3Pd      12 non-null     float64
#  14  0-3.1    12 non-null     float64
#  15  3-10.1   12 non-null     float64
#  16  10-16.1  12 non-null     float64
#  17  16-3P.1  10 non-null     float64
# dtypes: float64(11), int64(3), object(4)
# memory usage: 1.8+ KB

# %%
old_jazz_3_df.columns = old_jazz_3_df.columns.str.lower()
old_jazz_3_df.head()
# Out:
#                name   season  age   tm pos   g    mp  dist.    2pd    0-3  \
# 0  Donovan Mitchell  2019-20   23  UTA  SG  69  2364   14.8  0.648  0.169
# 1  Donovan Mitchell  2020-21   24  UTA  PG  53  1771   16.0  0.577  0.157
# 2  Donovan Mitchell  2021-22   25  UTA  SG  67  2266   16.7  0.525  0.140
# 3       Rudy Gobert  2019-20   27  UTA   C  68  2333    2.1  1.000  0.837
# 4       Rudy Gobert  2020-21   28  UTA   C  71  2187    2.7  0.993  0.770
#
#     3-10  10-16  16-3p    3pd  0-3.1  3-10.1  10-16.1  16-3p.1
# 0  0.229  0.134  0.115  0.352  0.626   0.414    0.489    0.465
# 1  0.219  0.093  0.108  0.423  0.608   0.418    0.451    0.424
# 2  0.236  0.077  0.072  0.475  0.708   0.465    0.519    0.434
# 3  0.158  0.005  0.000  0.000  0.755   0.386    0.000      NaN
# 4  0.209  0.005  0.009  0.007  0.798   0.281    0.000    0.200

# %%
old_jazz_3_df = old_jazz_3_df.fillna(0.000)
old_jazz_3_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     12 non-null     object
#  1   season   12 non-null     object
#  2   age      12 non-null     int64
#  3   tm       12 non-null     object
#  4   pos      12 non-null     object
#  5   g        12 non-null     int64
#  6   mp       12 non-null     int64
#  7   dist.    12 non-null     float64
#  8   2pd      12 non-null     float64
#  9   0-3      12 non-null     float64
#  10  3-10     12 non-null     float64
#  11  10-16    12 non-null     float64
#  12  16-3p    12 non-null     float64
#  13  3pd      12 non-null     float64
#  14  0-3.1    12 non-null     float64
#  15  3-10.1   12 non-null     float64
#  16  10-16.1  12 non-null     float64
#  17  16-3p.1  12 non-null     float64
# dtypes: float64(11), int64(3), object(4)
# memory usage: 1.8+ KB

# %%
new_jazz_3_df['age'] = new_jazz_3_df['age'].astype(str)
old_jazz_3_df['age'] = old_jazz_3_df['age'].astype(str)

# %%
new_jazz_df = pd.merge(new_jazz_df, new_jazz_3_df, on=[
    'name', 'season', 'age', 'tm', 'pos', 'mp'
], how='inner')

# %%
new_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 41
# Data columns (total 62 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     42 non-null     object
#  1   season   42 non-null     object
#  2   age      42 non-null     object
#  3   tm       42 non-null     object
#  4   pos      42 non-null     object
#  5   g_x      42 non-null     int64
#  6   mp       42 non-null     int64
#  7   per      42 non-null     float64
#  8   ts%      42 non-null     float64
#  9   3par     42 non-null     float64
#  10  ftr      42 non-null     float64
#  11  orb%     42 non-null     float64
#  12  drb%     42 non-null     float64
#  13  trb%     42 non-null     float64
#  14  ast%     42 non-null     float64
#  15  stl%     42 non-null     float64
#  16  blk%     42 non-null     float64
#  17  tov%     42 non-null     float64
#  18  usg%     42 non-null     float64
#  19  ows      42 non-null     float64
# ...

# %%
new_jazz_df = new_jazz_df.drop(columns='g_y', axis=1)
new_jazz_df = new_jazz_df.rename(columns={'g_x':'g'})
new_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 41
# Data columns (total 61 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     42 non-null     object
#  1   season   42 non-null     object
#  2   age      42 non-null     object
#  3   tm       42 non-null     object
#  4   pos      42 non-null     object
#  5   g        42 non-null     int64
#  6   mp       42 non-null     int64
#  7   per      42 non-null     float64
#  8   ts%      42 non-null     float64
#  9   3par     42 non-null     float64
#  10  ftr      42 non-null     float64
#  11  orb%     42 non-null     float64
#  12  drb%     42 non-null     float64
#  13  trb%     42 non-null     float64
#  14  ast%     42 non-null     float64
#  15  stl%     42 non-null     float64
#  16  blk%     42 non-null     float64
#  17  tov%     42 non-null     float64
#  18  usg%     42 non-null     float64
#  19  ows      42 non-null     float64
# ...

# %%
new_jazz_df
# Out:
#                    name   season age   tm  pos   g    mp   per    ts%   3par  \
# 0       Lauri Markkanen  2019-20  22  CHI   PF  50  1492  14.3  0.560  0.536
# 1       Lauri Markkanen  2020-21  23  CHI   PF  51  1317  15.2  0.619  0.568
# 2       Lauri Markkanen  2021-22  24  CLE   SF  61  1878  14.7  0.582  0.541
# 3          Kelly Olynyk  2019-20  28  MIA    C  67  1300  14.6  0.621  0.588
# 4          Kelly Olynyk  2020-21  29  TOT  CPF  70  1997  16.4  0.610  0.528
# 5          Kelly Olynyk  2020-21  29  TOT  CPF  70  1997  16.4  0.610  0.528
# 6          Kelly Olynyk  2020-21  29  TOT  CPF  70  1997  16.4  0.610  0.528
# 7          Kelly Olynyk  2020-21  29  MIA    C  43  1157  12.1  0.549  0.646
# 8          Kelly Olynyk  2020-21  29  MIA    C  43  1157  12.1  0.549  0.646
# 9          Kelly Olynyk  2020-21  29  MIA    C  43  1157  12.1  0.549  0.646
# 10         Kelly Olynyk  2020-21  29  HOU   PF  27   840  22.3  0.674  0.389
# ...

# %%
old_jazz_df = pd.merge(old_jazz_df, old_jazz_3_df, on=[
    'name', 'season', 'age', 'tm', 'pos', 'mp', 'g'
], how='inner')

# %%
old_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 11
# Data columns (total 61 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     12 non-null     object
#  1   season   12 non-null     object
#  2   age      12 non-null     object
#  3   tm       12 non-null     object
#  4   pos      12 non-null     object
#  5   g        12 non-null     int64
#  6   mp       12 non-null     int64
#  7   per      12 non-null     float64
#  8   ts%      12 non-null     float64
#  9   3par     12 non-null     float64
#  10  ftr      12 non-null     float64
#  11  orb%     12 non-null     float64
#  12  drb%     12 non-null     float64
#  13  trb%     12 non-null     float64
#  14  ast%     12 non-null     float64
#  15  stl%     12 non-null     float64
#  16  blk%     12 non-null     float64
#  17  tov%     12 non-null     float64
#  18  usg%     12 non-null     float64
#  19  ows      12 non-null     float64
# ...

# %%
new_jazz_df = new_jazz_df.rename(columns={
    '0-3':'0-3d', '3-10':'3-10d', '10-16':'10-16d', '16-3p':'16-3pd', '0-3.1':'0-3', '3-10.1':'3-10', '10-16.1':'10-16', '16-3p.1':'16-3p'
                                         })

# %%
new_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 41
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    42 non-null     object
#  1   season  42 non-null     object
#  2   age     42 non-null     object
#  3   tm      42 non-null     object
#  4   pos     42 non-null     object
#  5   g       42 non-null     int64
#  6   mp      42 non-null     int64
#  7   per     42 non-null     float64
#  8   ts%     42 non-null     float64
#  9   3par    42 non-null     float64
#  10  ftr     42 non-null     float64
#  11  orb%    42 non-null     float64
#  12  drb%    42 non-null     float64
#  13  trb%    42 non-null     float64
#  14  ast%    42 non-null     float64
#  15  stl%    42 non-null     float64
#  16  blk%    42 non-null     float64
#  17  tov%    42 non-null     float64
#  18  usg%    42 non-null     float64
#  19  ows     42 non-null     float64
#  20  dws     42 non-null     float64
# ...

# %%
old_jazz_df = old_jazz_df.rename(columns={
    '0-3':'0-3d', '3-10':'3-10d', '10-16':'10-16d', '16-3p':'16-3pd', '0-3.1':'0-3', '3-10.1':'3-10', '10-16.1':'10-16', '16-3p.1':'16-3p'
                                         })

# %%
old_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 0 to 11
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    12 non-null     object
#  1   season  12 non-null     object
#  2   age     12 non-null     object
#  3   tm      12 non-null     object
#  4   pos     12 non-null     object
#  5   g       12 non-null     int64
#  6   mp      12 non-null     int64
#  7   per     12 non-null     float64
#  8   ts%     12 non-null     float64
#  9   3par    12 non-null     float64
#  10  ftr     12 non-null     float64
#  11  orb%    12 non-null     float64
#  12  drb%    12 non-null     float64
#  13  trb%    12 non-null     float64
#  14  ast%    12 non-null     float64
#  15  stl%    12 non-null     float64
#  16  blk%    12 non-null     float64
#  17  tov%    12 non-null     float64
#  18  usg%    12 non-null     float64
#  19  ows     12 non-null     float64
#  20  dws     12 non-null     float64
# ...

# %%
old_jazz_df = old_jazz_df.fillna(0.000)

# %%
lmarkkanen_df = new_jazz_df.loc[new_jazz_df['name'] == 'Lauri Markkanen']
kolynyk_df = new_jazz_df.loc[new_jazz_df['name'] == 'Kelly Olynyk']
jvanderbilt_df = new_jazz_df.loc[new_jazz_df['name'] == 'Jarred Vanderbilt']
csexton_df = new_jazz_df.loc[new_jazz_df['name'] == 'Collin Sexton']
thortontucker_df = new_jazz_df.loc[new_jazz_df['name'] == 'Talen Horton-Tucker']
mbeasley_df = new_jazz_df.loc[new_jazz_df['name'] == 'Malik Beasley']

# %%
dmitchell_df = old_jazz_df.loc[old_jazz_df['name'] == 'Donovan Mitchell']
rgobert_df = old_jazz_df.loc[old_jazz_df['name'] == 'Rudy Gobert']
roneale_df = old_jazz_df.loc[old_jazz_df["name"] == "Royce O'Neale"]
bbogdanovic_df = old_jazz_df.loc[old_jazz_df['name'] == 'Bojan Bogdanovic']

# %%
sns.kdeplot(dmitchell_df['10-16d'], dmitchell_df['10-16'], color='r', shade=True, cmap='Reds')
plt.xlim(0,0.5)
plt.ylim(0,1.0)
# Out:
# C:\Users\18016\anaconda3-1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 1.0)

# %%
sns.kdeplot(lmarkkanen_df['10-16d'], lmarkkanen_df['10-16'], color='r', shade=True, cmap='Reds')
plt.xlim(0,0.5)
plt.ylim(0,1.0)
# Out:
# C:\Users\18016\anaconda3-1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 1.0)

# %%
sns.kdeplot(dmitchell_df['16-3pd'], dmitchell_df['16-3p'], color='r', shade=True, cmap='Reds')
plt.xlim(0,0.5)
plt.ylim(0,1.0)
# Out:
# C:\Users\18016\anaconda3-1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 1.0)

# %%
sns.kdeplot(lmarkkanen_df['16-3pd'], lmarkkanen_df['16-3p'], color='r', shade=True, cmap='Reds')
plt.xlim(0,0.5)
plt.ylim(0,1.0)
# Out:
# C:\Users\18016\anaconda3-1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 1.0)

# %%
sns.kdeplot(new_jazz_df['3p%'], new_jazz_df['3pd'], color='r', shade=True, cmap='Reds')
plt.xlim(0,1.0)
plt.ylim(0,1.0)
# Out:
# C:\Users\18016\anaconda3-1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 1.0)

# %%
sns.kdeplot(old_jazz_df['3p%'], old_jazz_df['3pd'], color='r', shade=True, cmap='Reds')
plt.xlim(0,1.0)
plt.ylim(0,1.0)
# Out:
# C:\Users\18016\anaconda3-1\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# (0.0, 1.0)

# %%
new_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 41
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    42 non-null     object
#  1   season  42 non-null     object
#  2   age     42 non-null     object
#  3   tm      42 non-null     object
#  4   pos     42 non-null     object
#  5   g       42 non-null     int64
#  6   mp      42 non-null     int64
#  7   per     42 non-null     float64
#  8   ts%     42 non-null     float64
#  9   3par    42 non-null     float64
#  10  ftr     42 non-null     float64
#  11  orb%    42 non-null     float64
#  12  drb%    42 non-null     float64
#  13  trb%    42 non-null     float64
#  14  ast%    42 non-null     float64
#  15  stl%    42 non-null     float64
#  16  blk%    42 non-null     float64
#  17  tov%    42 non-null     float64
#  18  usg%    42 non-null     float64
#  19  ows     42 non-null     float64
#  20  dws     42 non-null     float64
# ...

# %%
new_jazz_df = new_jazz_df.fillna(0.000)
new_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42 entries, 0 to 41
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    42 non-null     object
#  1   season  42 non-null     object
#  2   age     42 non-null     object
#  3   tm      42 non-null     object
#  4   pos     42 non-null     object
#  5   g       42 non-null     int64
#  6   mp      42 non-null     int64
#  7   per     42 non-null     float64
#  8   ts%     42 non-null     float64
#  9   3par    42 non-null     float64
#  10  ftr     42 non-null     float64
#  11  orb%    42 non-null     float64
#  12  drb%    42 non-null     float64
#  13  trb%    42 non-null     float64
#  14  ast%    42 non-null     float64
#  15  stl%    42 non-null     float64
#  16  blk%    42 non-null     float64
#  17  tov%    42 non-null     float64
#  18  usg%    42 non-null     float64
#  19  ows     42 non-null     float64
#  20  dws     42 non-null     float64
# ...

# %%
spearmanr(old_jazz_df['usg%'], old_jazz_df['ws/48'])
# Out:
# SpearmanrResult(correlation=0.0665500144921429, pvalue=0.8371878544641639)

# %%
pearsonr(old_jazz_df['usg%'], old_jazz_df['tov%'])
# Out:
# (-0.7887563135323046, 0.002295175545105514)

# %%
spearmanr(new_jazz_df['16-3pd'], new_jazz_df['16-3p'])
# Out:
# SpearmanrResult(correlation=0.5640239887878854, pvalue=0.00010024433863244196)

# %%
with pd.option_context('display.max_columns', 56):
    print(old_jazz_df.describe())
# Out:
#                g           mp        per        ts%       3par        ftr  \
# count  12.000000    12.000000  12.000000  12.000000  12.000000  12.000000
# mean   68.083333  2180.583333  17.216667   0.615667   0.401583   0.353917
# std     5.884623   170.733955   5.478526   0.056714   0.261788   0.248324
# min    53.000000  1771.000000   9.500000   0.558000   0.000000   0.117000
# 25%    66.750000  2110.750000  13.075000   0.576500   0.266000   0.208000
# 50%    69.000000  2201.500000  17.250000   0.599000   0.482000   0.283000
# 75%    71.000000  2282.750000  21.625000   0.626750   0.545000   0.383500
# max    77.000000  2406.000000  24.700000   0.732000   0.706000   0.864000
#
#             orb%       drb%       trb%       ast%       stl%       blk%  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean    5.066667  18.158333  11.850000  12.825000   1.250000   1.941667
# std     4.316213   9.817559   7.102432   7.912605   0.421038   2.429911
# ...

# %%
with pd.option_context('display.max_columns', 56):
    print(new_jazz_df.describe())
# Out:
#                g           mp        per        ts%       3par        ftr  \
# count  42.000000    42.000000  42.000000  42.000000  42.000000  42.000000
# mean   38.238095   951.000000  13.416667   0.588571   0.440619   0.330881
# std    24.318827   697.520871   3.910144   0.061792   0.255333   0.481858
# min     2.000000     5.000000   7.200000   0.503000   0.000000   0.000000
# 25%    11.750000   352.750000  11.100000   0.544500   0.275500   0.124000
# 50%    41.000000   989.500000  12.700000   0.571500   0.505500   0.239000
# 75%    60.000000  1313.750000  16.200000   0.617250   0.535750   0.262750
# max    79.000000  2143.000000  22.300000   0.714000   1.000000   2.000000
#
#             orb%       drb%       trb%       ast%       stl%       blk%  \
# count  42.000000  42.000000  42.000000  42.000000  42.000000  42.000000
# mean    4.080952  16.307143  10.114286  10.926190   1.900000   1.342857
# std     2.838777   5.591256   3.467520   5.987347   0.998047   0.891188
# ...

# %%
current_jazz_df = pd.read_csv('2023_jazz_stats.csv')
current_jazz_df
# Out:
#                   Name   Season  Age   Tm Pos   G   MP   PER    TS%   3PAr  \
# 0      Lauri Markkanen  2022-23   25  UTA  SF  11  371  22.2  0.623  0.407
# 1         Kelly Olynyk  2022-23   31  UTA  PF  11  301  15.4  0.692  0.395
# 2    Jarred Vanderbilt  2022-23   23  UTA  PF  10  254  16.3  0.620  0.167
# 3        Collin Sexton  2022-23   24  UTA  SG  11  244  17.5  0.607  0.345
# 4  Talen Horton-Tucker  2022-23   22  UTA  SG  11  178  11.5  0.470  0.446
# 5        Malik Beasley  2022-23   26  UTA  SG  11  274  11.6  0.525  0.598
#
#    ...   3-10  10-16  16-3P   3P.1  Unnamed: 59   2P.2  0-3.1  3-10.1  \
# 0  ...  0.273  0.058  0.052  0.407          NaN  0.667  0.889   0.553
# 1  ...  0.221  0.047  0.058  0.395          NaN  0.538  0.542   0.632
# 2  ...  0.303  0.030  0.000  0.167          NaN  0.564  0.758   0.250
# 3  ...  0.291  0.091  0.009  0.345          NaN  0.514  0.690   0.406
# 4  ...  0.216  0.081  0.014  0.446          NaN  0.537  0.667   0.438
# ...

# %%
current_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 65 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         6 non-null      object
#  1   Season       6 non-null      object
#  2   Age          6 non-null      int64
#  3   Tm           6 non-null      object
#  4   Pos          6 non-null      object
#  5   G            6 non-null      int64
#  6   MP           6 non-null      int64
#  7   PER          6 non-null      float64
#  8   TS%          6 non-null      float64
#  9   3PAr         6 non-null      float64
#  10  FTr          6 non-null      float64
#  11  ORB%         6 non-null      float64
#  12  DRB%         6 non-null      float64
#  13  TRB%         6 non-null      float64
#  14  AST%         6 non-null      float64
#  15  STL%         6 non-null      float64
#  16  BLK%         6 non-null      float64
#  17  TOV%         6 non-null      float64
# ...

# %%
current_jazz_df = current_jazz_df.drop(columns=[
    'Unnamed: 19', 'Unnamed: 24', 'Unnamed: 52', 'Unnamed: 59'
])

# %%
current_jazz_df.columns = current_jazz_df.columns.str.lower()
current_jazz_df.head()
# Out:
#                   name   season  age   tm pos   g   mp   per    ts%   3par  \
# 0      Lauri Markkanen  2022-23   25  UTA  SF  11  371  22.2  0.623  0.407
# 1         Kelly Olynyk  2022-23   31  UTA  PF  11  301  15.4  0.692  0.395
# 2    Jarred Vanderbilt  2022-23   23  UTA  PF  10  254  16.3  0.620  0.167
# 3        Collin Sexton  2022-23   24  UTA  SG  11  244  17.5  0.607  0.345
# 4  Talen Horton-Tucker  2022-23   22  UTA  SG  11  178  11.5  0.470  0.446
#
#    ...    0-3   3-10  10-16  16-3p   3p.1   2p.2  0-3.1  3-10.1  10-16.1  \
# 0  ...  0.209  0.273  0.058  0.052  0.407  0.667  0.889   0.553    0.700
# 1  ...  0.279  0.221  0.047  0.058  0.395  0.538  0.542   0.632    0.250
# 2  ...  0.500  0.303  0.030  0.000  0.167  0.564  0.758   0.250    0.500
# 3  ...  0.264  0.291  0.091  0.009  0.345  0.514  0.690   0.406    0.400
# 4  ...  0.243  0.216  0.081  0.014  0.446  0.537  0.667   0.438    0.333
#
#    16-3p.1
# 0    0.333
# 1    0.400
# 2    0.000
# 3    0.000
# 4    1.000
# ...

# %%
current_jazz_df['age'] = current_jazz_df['age'].astype(str)

# %%
current_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 61 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     6 non-null      object
#  1   season   6 non-null      object
#  2   age      6 non-null      object
#  3   tm       6 non-null      object
#  4   pos      6 non-null      object
#  5   g        6 non-null      int64
#  6   mp       6 non-null      int64
#  7   per      6 non-null      float64
#  8   ts%      6 non-null      float64
#  9   3par     6 non-null      float64
#  10  ftr      6 non-null      float64
#  11  orb%     6 non-null      float64
#  12  drb%     6 non-null      float64
#  13  trb%     6 non-null      float64
#  14  ast%     6 non-null      float64
#  15  stl%     6 non-null      float64
#  16  blk%     6 non-null      float64
#  17  tov%     6 non-null      float64
#  18  usg%     6 non-null      float64
#  19  ows      6 non-null      float64
# ...

# %%
current_jazz_df = current_jazz_df.rename(columns={
    '0-3':'0-3d', '3-10':'3-10d', '10-16':'10-16d', '16-3p':'16-3pd', '0-3.1':'0-3', '3-10.1':'3-10', '10-16.1':'10-16', '16-3p.1':'16-3p', '2p.1':'2pd', '3p.1':'3pd'
                                         })

# %%
current_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   season  6 non-null      object
#  2   age     6 non-null      object
#  3   tm      6 non-null      object
#  4   pos     6 non-null      object
#  5   g       6 non-null      int64
#  6   mp      6 non-null      int64
#  7   per     6 non-null      float64
#  8   ts%     6 non-null      float64
#  9   3par    6 non-null      float64
#  10  ftr     6 non-null      float64
#  11  orb%    6 non-null      float64
#  12  drb%    6 non-null      float64
#  13  trb%    6 non-null      float64
#  14  ast%    6 non-null      float64
#  15  stl%    6 non-null      float64
#  16  blk%    6 non-null      float64
#  17  tov%    6 non-null      float64
#  18  usg%    6 non-null      float64
#  19  ows     6 non-null      float64
#  20  dws     6 non-null      float64
# ...

# %%
current_jazz_df.describe()
# Out:
#                g          mp        per       ts%      3par       ftr  \
# count   6.000000    6.000000   6.000000  6.000000  6.000000  6.000000
# mean   10.833333  270.333333  15.750000  0.589500  0.393000  0.252167
# std     0.408248   64.145668   4.009364  0.079127  0.140295  0.114153
# min    10.000000  178.000000  11.500000  0.470000  0.167000  0.093000
# 25%    11.000000  246.500000  12.550000  0.545500  0.357500  0.188750
# 50%    11.000000  264.000000  15.850000  0.613500  0.401000  0.250000
# 75%    11.000000  294.250000  17.200000  0.622250  0.436250  0.312750
# max    11.000000  371.000000  22.200000  0.692000  0.598000  0.418000
#
#            orb%       drb%       trb%       ast%  ...      0-3d     3-10d  \
# count  6.000000   6.000000   6.000000   6.000000  ...  6.000000  6.000000
# mean   5.883333  15.583333  10.750000  13.050000  ...  0.261667  0.242333
# std    2.188531   7.065810   4.531997   4.336243  ...  0.137895  0.057729
# ...

# %%
with pd.option_context('display.max_columns', 60):
    print(current_jazz_df.describe())
# Out:
#                g          mp        per       ts%      3par       ftr  \
# count   6.000000    6.000000   6.000000  6.000000  6.000000  6.000000
# mean   10.833333  270.333333  15.750000  0.589500  0.393000  0.252167
# std     0.408248   64.145668   4.009364  0.079127  0.140295  0.114153
# min    10.000000  178.000000  11.500000  0.470000  0.167000  0.093000
# 25%    11.000000  246.500000  12.550000  0.545500  0.357500  0.188750
# 50%    11.000000  264.000000  15.850000  0.613500  0.401000  0.250000
# 75%    11.000000  294.250000  17.200000  0.622250  0.436250  0.312750
# max    11.000000  371.000000  22.200000  0.692000  0.598000  0.418000
#
#            orb%       drb%       trb%       ast%      stl%      blk%  \
# count  6.000000   6.000000   6.000000   6.000000  6.000000  6.000000
# mean   5.883333  15.583333  10.750000  13.050000  2.133333  1.283333
# std    2.188531   7.065810   4.531997   4.336243  0.697615  0.705455
# ...

# %%
current_jazz_df = current_jazz_df.drop(columns=['2p.2'], axis=1)
current_jazz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 60 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    6 non-null      object
#  1   season  6 non-null      object
#  2   age     6 non-null      object
#  3   tm      6 non-null      object
#  4   pos     6 non-null      object
#  5   g       6 non-null      int64
#  6   mp      6 non-null      int64
#  7   per     6 non-null      float64
#  8   ts%     6 non-null      float64
#  9   3par    6 non-null      float64
#  10  ftr     6 non-null      float64
#  11  orb%    6 non-null      float64
#  12  drb%    6 non-null      float64
#  13  trb%    6 non-null      float64
#  14  ast%    6 non-null      float64
#  15  stl%    6 non-null      float64
#  16  blk%    6 non-null      float64
#  17  tov%    6 non-null      float64
#  18  usg%    6 non-null      float64
#  19  ows     6 non-null      float64
#  20  dws     6 non-null      float64
# ...

# %%
with pd.option_context('display.max_columns', 59):
    print(current_jazz_df.describe())
# Out:
#                g          mp        per       ts%      3par       ftr  \
# count   6.000000    6.000000   6.000000  6.000000  6.000000  6.000000
# mean   10.833333  270.333333  15.750000  0.589500  0.393000  0.252167
# std     0.408248   64.145668   4.009364  0.079127  0.140295  0.114153
# min    10.000000  178.000000  11.500000  0.470000  0.167000  0.093000
# 25%    11.000000  246.500000  12.550000  0.545500  0.357500  0.188750
# 50%    11.000000  264.000000  15.850000  0.613500  0.401000  0.250000
# 75%    11.000000  294.250000  17.200000  0.622250  0.436250  0.312750
# max    11.000000  371.000000  22.200000  0.692000  0.598000  0.418000
#
#            orb%       drb%       trb%       ast%      stl%      blk%  \
# count  6.000000   6.000000   6.000000   6.000000  6.000000  6.000000
# mean   5.883333  15.583333  10.750000  13.050000  2.133333  1.283333
# std    2.188531   7.065810   4.531997   4.336243  0.697615  0.705455
# ...

# %%
with pd.option_context('display.max_columns', 59):
    print(new_jazz_df.describe())
# Out:
#                g           mp        per        ts%       3par        ftr  \
# count  42.000000    42.000000  42.000000  42.000000  42.000000  42.000000
# mean   38.238095   951.000000  13.416667   0.588571   0.440619   0.330881
# std    24.318827   697.520871   3.910144   0.061792   0.255333   0.481858
# min     2.000000     5.000000   7.200000   0.503000   0.000000   0.000000
# 25%    11.750000   352.750000  11.100000   0.544500   0.275500   0.124000
# 50%    41.000000   989.500000  12.700000   0.571500   0.505500   0.239000
# 75%    60.000000  1313.750000  16.200000   0.617250   0.535750   0.262750
# max    79.000000  2143.000000  22.300000   0.714000   1.000000   2.000000
#
#             orb%       drb%       trb%       ast%       stl%       blk%  \
# count  42.000000  42.000000  42.000000  42.000000  42.000000  42.000000
# mean    4.080952  16.307143  10.114286  10.926190   1.900000   1.342857
# std     2.838777   5.591256   3.467520   5.987347   0.998047   0.891188
# ...

# %%
team_df_2 = pd.read_csv('team_data_2.csv')
team_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      30 non-null     int64
#  1   Team    30 non-null     object
#  2   Conf    30 non-null     object
#  3   Div     30 non-null     object
#  4   W       30 non-null     int64
#  5   L       30 non-null     int64
#  6   W/L%    30 non-null     float64
#  7   MOV     30 non-null     float64
#  8   ORtg    30 non-null     float64
#  9   DRtg    30 non-null     float64
#  10  NRtg    30 non-null     float64
#  11  MOV/A   30 non-null     float64
#  12  ORtg/A  30 non-null     float64
#  13  DRtg/A  30 non-null     float64
#  14  NRtg/A  30 non-null     float64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 3.6+ KB

# %%
team_df_2 = team_df_2.drop(columns=['Rk'], axis=1)
team_df_2
# Out:
#                       Team Conf Div  W  L   W/L%    MOV    ORtg    DRtg  \
# 0      Cleveland Cavaliers    E   C  8  1  0.889  12.33  116.24  103.67
# 1             Phoenix Suns    W   P  7  2  0.778  11.22  118.83  107.22
# 2         Dallas Mavericks    W  SW  5  3  0.625   6.00  118.56  112.40
# 3          Toronto Raptors    E   A  6  4  0.600   7.30  116.84  109.98
# 4          Milwaukee Bucks    E   C  9  0  1.000  11.78  113.62  101.86
# 5           Boston Celtics    E   A  6  3  0.667   3.44  119.46  115.73
# 6     New Orleans Pelicans    W  SW  5  4  0.556   5.11  116.57  111.35
# 7                Utah Jazz    W  NW  8  3  0.727   4.55  115.07  110.73
# 8   Portland Trail Blazers    W  NW  6  3  0.667   0.67  112.02  111.45
# 9            Chicago Bulls    E   C  5  6  0.455   1.00  112.23  111.37
# 10       Memphis Grizzlies    W  SW  7  3  0.700   1.90  116.45  114.55
# 11      Philadelphia 76ers    E   A  4  6  0.400   0.60  115.00  114.38
# ...

# %%
team_df_2.columns = team_df_2.columns.str.lower()
team_df_2
# Out:
#                       team conf div  w  l   w/l%    mov    ortg    drtg  \
# 0      Cleveland Cavaliers    E   C  8  1  0.889  12.33  116.24  103.67
# 1             Phoenix Suns    W   P  7  2  0.778  11.22  118.83  107.22
# 2         Dallas Mavericks    W  SW  5  3  0.625   6.00  118.56  112.40
# 3          Toronto Raptors    E   A  6  4  0.600   7.30  116.84  109.98
# 4          Milwaukee Bucks    E   C  9  0  1.000  11.78  113.62  101.86
# 5           Boston Celtics    E   A  6  3  0.667   3.44  119.46  115.73
# 6     New Orleans Pelicans    W  SW  5  4  0.556   5.11  116.57  111.35
# 7                Utah Jazz    W  NW  8  3  0.727   4.55  115.07  110.73
# 8   Portland Trail Blazers    W  NW  6  3  0.667   0.67  112.02  111.45
# 9            Chicago Bulls    E   C  5  6  0.455   1.00  112.23  111.37
# 10       Memphis Grizzlies    W  SW  7  3  0.700   1.90  116.45  114.55
# 11      Philadelphia 76ers    E   A  4  6  0.400   0.60  115.00  114.38
# ...

# %%
def get_image(path, zoom=0.03):
    return OffsetImage(plt.imread(path), zoom=zoom)

paths = [
    'https://i.postimg.cc/QCh75fB5/Cleveland-Cavaliers-Logo-PNG-Free-Download.png',
    'https://i.postimg.cc/9Mpdx3H1/phoenix-suns-logo-black-and-white-transparent.png',
    'https://i.postimg.cc/J7cvWSK3/36236-8-dallas-mavericks-clipart.png',
    'https://i.postimg.cc/FKMX63Sq/toronto-raptors-logo-black.png',
    'https://i.postimg.cc/TYH6MzMB/milwaukee-bucks-logo-transparent.png',
    'https://i.postimg.cc/v8KzCs6S/58419c6aa6515b1e0ad75a61.png',
    'https://i.postimg.cc/s2g0PJhk/new-orleans-pelicans-05.png',
    'https://i.postimg.cc/gJkL4NqP/image-asset.png',
    'https://i.postimg.cc/90bqQWtd/58419c2fa6515b1e0ad75a5d.png',
    'https://i.postimg.cc/MZyp3XYp/chicago-bulls-logo-transparent.png',
    'https://i.postimg.cc/VvFbfXkR/memphis-grizzlies-08.png',
    'https://i.postimg.cc/7ZhXRZKc/philadelphia-76-ers-11.png',
    'https://i.postimg.cc/NM93vxb3/brooklyn-nets-logo-transparent.png',
    'https://i.postimg.cc/vZjBr01j/denver-nuggets-06.png',
    'https://i.postimg.cc/x86WVFM3/miami-heat-logo-transparent.png',
    'https://i.postimg.cc/fRrgK9fk/new-york-knicks-logo-transparent.png',
    'https://i.postimg.cc/k4Q2sWKm/atlanta-hawks-logo-transparent.png',
    'https://i.postimg.cc/yNwfcCXG/minnesota-timberwolves-logo-transparent.png',
    'https://i.postimg.cc/tCxFnnm9/oklahoma-city-thunder-logo.png',
    'https://i.postimg.cc/pdqscnHg/sacramento-kings-logo-transparent.png',
    'https://i.postimg.cc/44wS2qJY/indiana-pacers-logo-transparent.png',
    'https://i.postimg.cc/yxqp0CBd/lakers-free-hd-logo-png-2.png',
    'https://i.postimg.cc/zvp6nPfR/orlando-magic-06.png',
    'https://i.postimg.cc/qRht39Mz/washington-wizards-logo-transparent.png',
    'https://i.postimg.cc/sDMCYspj/gsw-logo-1920.png',
    'https://i.postimg.cc/vmvbTXdC/charlotte-hornets-01.png',
    'https://i.postimg.cc/T3nS0wh6/58419c59a6515b1e0ad75a60.png',
    'https://i.postimg.cc/ZqyWGP9z/Houston-Rockets-logo-1.png',
    'https://i.postimg.cc/k4Gn68ss/san-antonio-spurs-21.png',
    'https://i.postimg.cc/HnGX6pVq/detroit-pistons-logo-transparent.png'
]

x = team_df_2['nrtg']
y = team_df_2['mov']

fig, ax = plt.subplots()
ax.scatter(x,y)
fig.set_dpi(550)
plt.axvline(0, c='black', ls='--')
plt.axhline(0, c='black', ls='--')
plt.title('Net Rating and Average Margin of Victory for All NBA Teams', fontsize=10)
plt.xlabel('Net Rating (through November 6, 2022)', fontsize=8)
plt.ylabel('Avg Margin of Victory (through November 6, 2022)', fontsize=8)
plt.grid()

for x0, y0, path in zip(x, y, paths):
    ab = AnnotationBbox(get_image(path), (x0, y0), frameon=False)
    ax.add_artist(ab)

plt.arrow(x=1.1,y=9.1,dx=2.1,dy=-2.7, shape='full', color='r', length_includes_head=True, width=0.07)
# Out:
# C:\Users\18016\AppData\Local\Temp\ipykernel_22820\615538595.py:2: MatplotlibDeprecationWarning: Directly reading images from URLs is deprecated since 3.4 and will no longer be supported two minor releases later. Please open the URL for reading and pass the result to Pillow, e.g. with ``np.array(PIL.Image.open(urllib.request.urlopen(url)))``.
#   return OffsetImage(plt.imread(path), zoom=zoom)

# %%
plt.figure(figsize=(12,6))
ax = sns.boxplot(x=old_jazz_df['ws'])
plt.xlim(0,15)
# Out:
# (0.0, 15.0)

# %%
plt.figure(figsize=(12,6))
ax = sns.boxplot(x=new_jazz_df['ws'])
plt.xlim(0,15)
# Out:
# (0.0, 15.0)

# %%
plt.figure(figsize=(12,6))
ax = sns.scatterplot(data=old_jazz_df, x='obpm', y='dbpm')
plt.xlim(-10,10)
plt.ylim(-5,5)
plt.axvline(0, c='black', ls='--')
plt.axhline(0, c='black', ls='--')
plt.grid()

# %%
plt.figure(figsize=(12,6))
ax = sns.scatterplot(data=new_jazz_df, x='obpm', y='dbpm')
plt.xlim(-10,10)
plt.ylim(-5,5)
plt.axvline(0, c='black', ls='--')
plt.axhline(0, c='black', ls='--')
plt.grid()

# %%
plt.figure(figsize=(12,6))
ax = sns.scatterplot(data=current_jazz_df, x='obpm', y='dbpm')
plt.xlim(-10,10)
plt.ylim(-5,5)
plt.axvline(0, c='black', ls='--')
plt.axhline(0, c='black', ls='--')
plt.grid()

# %%
new_jazz_df.to_csv('new_jazz_df.csv', index=False)
old_jazz_df.to_csv('old_jazz_df.csv', index=False)

# %%
current_jazz_df.to_csv('2023_jazz_df.csv', index=False)
